# %% [markdown]
# ***Exam 2***
#
#
# Exam 2 Author: Kayce Johnson

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# This stops a few warning messages from showing
pd.options.mode.chained_assignment = None 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Load the data.
file_name = 'flights'
file_location = 'https://joannabieri.com/introdatascience/data/'+file_name+'.csv'
DF = pd.read_csv(file_location)
DF
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  850       33.0      AA    1141  N619AA    JFK  MIA
# 3                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 4                  837      -25.0      DL     461  N668DN    LGA  ATL
# ...                ...        ...     ...     ...     ...    ...  ...
# 336771            1634        NaN      9E    3393     NaN    JFK  DCA
# 336772            2312        NaN      9E    3525     NaN    LGA  SYR
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute            time_hour
# 0          227.0    1400.0   5.0    15.0  2013-01-01 10:00:00
# 1          227.0    1416.0   5.0    29.0  2013-01-01 10:00:00
# 2          160.0    1089.0   5.0    40.0  2013-01-01 10:00:00
# 3          183.0    1576.0   5.0    45.0  2013-01-01 10:00:00
# 4          116.0     762.0   6.0     0.0  2013-01-01 11:00:00
# ...          ...       ...   ...     ...                  ...
# 336771       NaN     213.0  14.0    55.0  2013-09-30 18:00:00
# 336772       NaN     198.0  22.0     0.0  2013-10-01 02:00:00
# 336773       NaN     764.0  12.0    10.0  2013-09-30 16:00:00
# 336774       NaN     419.0  11.0    59.0  2013-09-30 15:00:00
# 336775       NaN     431.0   8.0    40.0  2013-09-30 12:00:00
#
# [336776 rows x 19 columns]

# %%
file_name = 'airports'
file_location = 'https://joannabieri.com/introdatascience/data/'+file_name+'.csv'
DF_airports = pd.read_csv(file_location)
show(DF_airports)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_1b472986_75e0_4d91_a3db_912e2f45393e"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_1b472986_75e0_4d91_a3db_912e2f45393e:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 1,458 rows as maxBytes=64KB", "filtered_row_count": 435, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>faa</th>\n      <th>name</th>\n      <th>lat</th>\n      <th>lon</th>\n      <th>alt</th>\n      <th>tz</th>\n      <th>dst</th>\n      <th>tzone</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"04G\", \"Lansdowne Airport\", 41.130472, -80.619583, 1044.0, -5.0, \"A\", \"America/New_York\"], [\"06A\", \"Moton Field Municipal Airport\", 32.460572, -85.680028, 264.0, -6.0, \"A\", \"America/Chicago\"], [\"06C\", \"Schaumburg Regional\", 41.989341, -88.101243, 801.0, -6.0, \"A\", \"America/Chicago\"], [\"06N\", \"Randall Airport\", 41.431912, -74.391561, 523.0, -5.0, \"A\", \"America/New_York\"], [\"09J\", \"Jekyll Island Airport\", 31.074472, -81.427778, 11.0, -5.0, \"A\", \"America/New_York\"], [\"0A9\", \"Elizabethton Municipal Airport\", 36.371222, -82.173417, 1593.0, -5.0, \"A\", \"America/New_York\"], [\"0G6\", \"Williams County Airport\", 41.467306, -84.506778, 730.0, -5.0, \"A\", \"America/New_York\"], [\"0G7\", \"Finger Lakes Regional Airport\", 42.883565, -76.781232, 492.0, -5.0, \"A\", \"America/New_York\"], [\"0P2\", \"Shoestring Aviation Airfield\", 39.794824, -76.647191, 1000.0, -5.0, \"U\", \"America/New_York\"], [\"0S9\", \"Jefferson County Intl\", 48.053809, -122.810644, 108.0, -8.0, \"A\", \"America/Los_Angeles\"], [\"0W3\", \"Harford County Airport\", 39.566838, -76.202403, 409.0, -5.0, \"A\", \"America/New_York\"], [\"10C\", \"Galt Field Airport\", 42.402889, -88.375111, 875.0, -6.0, \"U\", \"America/Chicago\"], [\"17G\", \"Port Bucyrus-Crawford County Airport\", 40.781556, -82.974806, 1003.0, -5.0, \"A\", \"America/New_York\"], [\"19A\", \"Jackson County Airport\", 34.175864, -83.561597, 951.0, -5.0, \"U\", \"America/New_York\"], [\"1A3\", \"Martin Campbell Field Airport\", 35.015806, -84.346833, 1789.0, -5.0, \"A\", \"America/New_York\"], [\"1B9\", \"Mansfield Municipal\", 42.000133, -71.196771, 122.0, -5.0, \"A\", \"America/New_York\"], [\"1C9\", \"Frazier Lake Airpark\", 54.013333, -124.768333, 152.0, -8.0, \"A\", \"America/Vancouver\"], [\"1CS\", \"Clow International Airport\", 41.695974, -88.129231, 670.0, -6.0, \"U\", \"America/Chicago\"], [\"1G3\", \"Kent State Airport\", 41.151389, -81.415111, 1134.0, -5.0, \"A\", \"America/New_York\"], [\"1G4\", \"Grand Canyon West Airport\", 35.899904, -113.815674, 4813.0, -7.0, \"A\", \"America/Phoenix\"], [\"1H2\", \"Effingham Memorial Airport\", 39.07, -88.534, 585.0, -6.0, \"A\", \"America/Chicago\"], [\"1OH\", \"Fortman Airport\", 40.555325, -84.386619, 885.0, -5.0, \"U\", \"America/New_York\"], [\"1RL\", \"Point Roberts Airpark\", 48.979722, -123.078889, 10.0, -8.0, \"A\", \"America/Los_Angeles\"], [\"23M\", \"Clarke CO\", 32.0517, -88.4434, 320.0, -6.0, \"A\", \"America/Chicago\"], [\"24C\", \"Lowell City Airport\", 42.95392, -85.343906, 681.0, -5.0, \"A\", \"America/New_York\"], [\"24J\", \"Suwannee County Airport\", 30.300125, -83.024694, 104.0, -5.0, \"A\", \"America/New_York\"], [\"25D\", \"Forest Lake Airport\", 45.247746, -92.994385, 925.0, -6.0, \"A\", \"America/Chicago\"], [\"29D\", \"Grove City Airport\", 41.146028, -80.16775, 1371.0, -5.0, \"A\", \"America/New_York\"], [\"2A0\", \"Mark Anton Airport\", 35.48625, -84.931083, 718.0, -5.0, \"A\", \"America/New_York\"], [\"2B2\", \"Plum Island Airport\", 42.795361, -70.839444, 11.0, -5.0, \"A\", \"America/New_York\"], [\"2G2\", \"Jefferson County Airpark\", 40.360218, -80.700874, 1196.0, -5.0, \"A\", \"America/New_York\"], [\"2G9\", \"Somerset C ...

# %%
DF.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  336776.0  336776.000000  336776.000000  328521.000000   336776.000000
# mean     2013.0       6.548510      15.710787    1349.109947     1344.254840
# std         0.0       3.414457       8.768607     488.281791      467.335756
# min      2013.0       1.000000       1.000000       1.000000      106.000000
# 25%      2013.0       4.000000       8.000000     907.000000      906.000000
# 50%      2013.0       7.000000      16.000000    1401.000000     1359.000000
# 75%      2013.0      10.000000      23.000000    1744.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  328521.000000  328063.000000   336776.000000  327346.000000
# mean       12.639070    1502.054999     1536.380220       6.895377
# std        40.210061     533.264132      497.457142      44.633292
# min       -43.000000       1.000000        1.000000     -86.000000
# 25%        -5.000000    1104.000000     1124.000000     -17.000000
# 50%        -2.000000    1535.000000     1556.000000      -5.000000
# 75%        11.000000    1940.000000     1945.000000      14.000000
# max      1301.000000    2400.000000     2359.000000    1272.000000
#
#               flight       air_time       distance           hour  \
# count  336776.000000  327346.000000  336776.000000  336776.000000
# mean     1971.923620     150.686460    1039.912604      13.180247
# std      1632.471938      93.688305     733.233033       4.661316
# min         1.000000      20.000000      17.000000       1.000000
# 25%       553.000000      82.000000     502.000000       9.000000
# 50%      1496.000000     129.000000     872.000000      13.000000
# 75%      3465.000000     192.000000    1389.000000      17.000000
# max      8500.000000     695.000000    4983.000000      23.000000
#
#               minute
# count  336776.000000
# mean       26.230100
# std        19.300846
# min         0.000000
# 25%         8.000000
# 50%        29.000000
# 75%        44.000000
# max        59.000000

# %% [markdown]
# There are 336776 observations across 19 variables. There are a lot on NaNs - particularly in air time, deploy time, and deployed delay - which feels like flights that never left.
#
# Most variables are numerical, except the ailnum,	origin, and	dest. The time variable will need some work before it can be treated as a numerical variable.

# %% [markdown]
# ***Question 1***

# %%
my_columns = ['origin', 'dest']
DF1 = DF[my_columns]
DF1

show(DF1.groupby('origin')['dest'].value_counts())
show(DF1.value_counts())
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_e0148578_70ca_4417_a72b_68407bcbaeac"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_e0148578_70ca_4417_a72b_68407bcbaeac:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>origin</th>\n      <th>dest</th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"EWR\", \"ORD\", 6100], [\"EWR\", \"BOS\", 5327], [\"EWR\", \"SFO\", 5127], [\"EWR\", \"CLT\", 5026], [\"EWR\", \"ATL\", 5022], [\"EWR\", \"MCO\", 4941], [\"EWR\", \"LAX\", 4912], [\"EWR\", \"IAH\", 3973], [\"EWR\", \"FLL\", 3793], [\"EWR\", \"DTW\", 3178], [\"EWR\", \"DFW\", 3148], [\"EWR\", \"DEN\", 2859], [\"EWR\", \"PHX\", 2723], [\"EWR\", \"CVG\", 2673], [\"EWR\", \"MIA\", 2633], [\"EWR\", \"STL\", 2516], [\"EWR\", \"MSP\", 2377], [\"EWR\", \"PBI\", 2351], [\"EWR\", \"BNA\", 2336], [\"EWR\", \"TPA\", 2334], [\"EWR\", \"MDW\", 2043], [\"EWR\", \"LAS\", 2010], [\"EWR\", \"SEA\", 1831], [\"EWR\", \"CLE\", 1754], [\"EWR\", \"DCA\", 1719], [\"EWR\", \"RIC\", 1667], [\"EWR\", \"RDU\", 1482], [\"EWR\", \"RSW\", 1437], [\"EWR\", \"CHS\", 1424], [\"EWR\", \"MCI\", 1356], [\"EWR\", \"IND\", 1301], [\"EWR\", \"JAX\", 1242], [\"EWR\", \"IAD\", 1236], [\"EWR\", \"MSY\", 1155], [\"EWR\", \"DAY\", 1134], [\"EWR\", \"SAN\", 1134], [\"EWR\", \"GSO\", 1120], [\"EWR\", \"MKE\", 1094], [\"EWR\", \"SJU\", 1067], [\"EWR\", \"HOU\", 976], [\"EWR\", \"BUF\", 973], [\"EWR\", \"AUS\", 968], [\"EWR\", \"BTV\", 931], [\"EWR\", \"MEM\", 926], [\"EWR\", \"SDF\", 894], [\"EWR\", \"MHT\", 867], [\"EWR\", \"SNA\", 825], [\"EWR\", \"PWM\", 770], [\"EWR\", \"OMA\", 754], [\"EWR\", \"GSP\", 745], [\"EWR\", \"SAV\", 736], [\"EWR\", \"CMH\", 724], [\"EWR\", \"GRR\", 719], [\"EWR\", \"ORF\", 584], [\"EWR\", \"PDX\", 571], [\"EWR\", \"PIT\", 559], [\"EWR\", \"BWI\", 545], [\"EWR\", \"ROC\", 513], [\"EWR\", \"BDL\", 443], [\"EWR\", \"ALB\", 439], [\"EWR\", \"DSM\", 411], [\"EWR\", \"PVD\", 376], [\"EWR\", \"HNL\", 365], [\"EWR\", \"MSN\", 354], [\"EWR\", \"SLC\", 354], [\"EWR\", \"OKC\", 346], [\"EWR\", \"SAT\", 330], [\"EWR\", \"TYS\", 323], [\"EWR\", \"TUL\", 315], [\"EWR\", \"BQN\", 297], [\"EWR\", \"XNA\", 291], [\"EWR\", \"AVL\", 265], [\"EWR\", \"STT\", 189], [\"EWR\", \"SYR\", 157], [\"EWR\", \"EGE\", 110], [\"EWR\", \"CAE\", 104], [\"EWR\", \"MYR\", 56], [\"EWR\", \"PHL\", 49], [\"EWR\", \"BZN\", 36], [\"EWR\", \"TVC\", 24], [\"EWR\", \"JAC\", 23], [\"EWR\", \"HDN\", 15], [\"EWR\", \"MTJ\", 15], [\"EWR\", \"ANC\", 8], [\"EWR\", \"SBN\", 4], [\"EWR\", \"LGA\", 1], [\"JFK\", \"LAX\", 11262], [\"JFK\", \"SFO\", 8204], [\"JFK\", \"BOS\", 5898], [\"JFK\", \"MCO\", 5464], [\"JFK\", \"SJU\", 4752], [\"JFK\", \"FLL\", 4254], [\"JFK\", \"LAS\", 3987], [\"JFK\", \"BUF\", 3582], [\"JFK\", \"MIA\", 3314], [\"JFK\", \"DCA\", 3270], [\"JFK\", \"RDU\", 3100], [\"JFK\", \"TPA\", 2987], [\"JFK\", \"CLT\", 2870], [\"JFK\", \"IAD\", 2661], [\"JFK\", \"ORD\", 2326], [\"JFK\", \"SLC\", 2113], [\"JFK\", \"SEA\", 2092], [\"JFK\", \"PHX\", 1933], [\"JFK\", \"ATL\", 1930], [\"JFK\", \"PBI\", 1739], [\"JFK\", \"ROC\", 1679], [\"JFK\", \"MSY\", 1633], [\"JFK\", \"SAN\", 1603], [\"JFK\", \"AUS\", 1471], [\"JFK\", \"BTV\", 1364], [\"JFK\", \"RSW\", 1339], [\"JFK\", \"SYR\", 1311], [\"JFK\", \"PWM\", 1304], [\"JFK\", \"JAX\", 1299], [\"JFK\", \"PIT\", 1249], [\"JFK\", \"BWI\", 1221], [\"JFK\", \"DTW\", 1166], [\"JFK\", \"MSP\", 1095], [\"JFK\", \"CVG\", 997], [\"JFK\", \"PHL\", 976], [\"JFK\", \"CHS\", 960], [\"JFK\", \"PDX\", 783], [\"JFK\", \"ORF\", 746], [\"JFK\", \"CMH\", 742], [\"JFK\", \"DFW\", 732], [\"JFK\", \"BNA\", 730], [\"JFK\", \"HOU\", 714], [\"JFK\", \"CLE\", 707], [\"JFK\", \"DEN\", 703], [\"JFK\", \"IND\", 689], [\"JFK\", \"LGB\", 668], [\"JFK\", \"BQN\", 599], [\"JFK\", \"SRQ\", 474], [\"JFK\", \"BUR\", 371],  ...
# <!--| quarto-html-table-processing: none -->
# <table id="itables_3ff931ad_4f0f_4b24_9e07_579a0726a363"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_3ff931ad_4f0f_4b24_9e07_579a0726a363:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>origin</th>\n      <th>dest</th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"JFK\", \"LAX\", 11262], [\"LGA\", \"ATL\", 10263], [\"LGA\", \"ORD\", 8857], [\"JFK\", \"SFO\", 8204], [\"LGA\", \"CLT\", 6168], [\"EWR\", \"ORD\", 6100], [\"JFK\", \"BOS\", 5898], [\"LGA\", \"MIA\", 5781], [\"JFK\", \"MCO\", 5464], [\"EWR\", \"BOS\", 5327], [\"EWR\", \"SFO\", 5127], [\"LGA\", \"DTW\", 5040], [\"EWR\", \"CLT\", 5026], [\"EWR\", \"ATL\", 5022], [\"EWR\", \"MCO\", 4941], [\"EWR\", \"LAX\", 4912], [\"LGA\", \"DFW\", 4858], [\"JFK\", \"SJU\", 4752], [\"LGA\", \"DCA\", 4716], [\"LGA\", \"BOS\", 4283], [\"JFK\", \"FLL\", 4254], [\"LGA\", \"FLL\", 4008], [\"JFK\", \"LAS\", 3987], [\"EWR\", \"IAH\", 3973], [\"EWR\", \"FLL\", 3793], [\"LGA\", \"MSP\", 3713], [\"LGA\", \"DEN\", 3704], [\"LGA\", \"MCO\", 3677], [\"JFK\", \"BUF\", 3582], [\"LGA\", \"RDU\", 3581], [\"JFK\", \"MIA\", 3314], [\"JFK\", \"DCA\", 3270], [\"LGA\", \"BNA\", 3267], [\"EWR\", \"DTW\", 3178], [\"EWR\", \"DFW\", 3148], [\"JFK\", \"RDU\", 3100], [\"JFK\", \"TPA\", 2987], [\"LGA\", \"IAH\", 2951], [\"JFK\", \"CLT\", 2870], [\"EWR\", \"DEN\", 2859], [\"EWR\", \"PHX\", 2723], [\"EWR\", \"CVG\", 2673], [\"JFK\", \"IAD\", 2661], [\"EWR\", \"MIA\", 2633], [\"EWR\", \"STL\", 2516], [\"LGA\", \"PBI\", 2464], [\"EWR\", \"MSP\", 2377], [\"EWR\", \"PBI\", 2351], [\"EWR\", \"BNA\", 2336], [\"EWR\", \"TPA\", 2334], [\"JFK\", \"ORD\", 2326], [\"LGA\", \"TPA\", 2145], [\"JFK\", \"SLC\", 2113], [\"LGA\", \"CLE\", 2112], [\"JFK\", \"SEA\", 2092], [\"LGA\", \"MDW\", 2070], [\"LGA\", \"CMH\", 2058], [\"EWR\", \"MDW\", 2043], [\"EWR\", \"LAS\", 2010], [\"JFK\", \"PHX\", 1933], [\"JFK\", \"ATL\", 1930], [\"EWR\", \"SEA\", 1831], [\"LGA\", \"STL\", 1822], [\"LGA\", \"IAD\", 1803], [\"EWR\", \"CLE\", 1754], [\"JFK\", \"PBI\", 1739], [\"EWR\", \"DCA\", 1719], [\"JFK\", \"ROC\", 1679], [\"EWR\", \"RIC\", 1667], [\"JFK\", \"MSY\", 1633], [\"JFK\", \"SAN\", 1603], [\"LGA\", \"MKE\", 1525], [\"EWR\", \"RDU\", 1482], [\"JFK\", \"AUS\", 1471], [\"EWR\", \"RSW\", 1437], [\"EWR\", \"CHS\", 1424], [\"JFK\", \"BTV\", 1364], [\"EWR\", \"MCI\", 1356], [\"JFK\", \"RSW\", 1339], [\"JFK\", \"SYR\", 1311], [\"JFK\", \"PWM\", 1304], [\"EWR\", \"IND\", 1301], [\"JFK\", \"JAX\", 1299], [\"JFK\", \"PIT\", 1249], [\"EWR\", \"JAX\", 1242], [\"EWR\", \"IAD\", 1236], [\"JFK\", \"BWI\", 1221], [\"JFK\", \"DTW\", 1166], [\"EWR\", \"MSY\", 1155], [\"EWR\", \"DAY\", 1134], [\"EWR\", \"SAN\", 1134], [\"EWR\", \"GSO\", 1120], [\"JFK\", \"MSP\", 1095], [\"EWR\", \"MKE\", 1094], [\"EWR\", \"SJU\", 1067], [\"LGA\", \"PIT\", 1067], [\"LGA\", \"MSY\", 1011], [\"JFK\", \"CVG\", 997], [\"JFK\", \"PHL\", 976], [\"EWR\", \"HOU\", 976], [\"EWR\", \"BUF\", 973], [\"EWR\", \"AUS\", 968], [\"JFK\", \"CHS\", 960], [\"EWR\", \"BTV\", 931], [\"EWR\", \"MEM\", 926], [\"EWR\", \"SDF\", 894], [\"EWR\", \"MHT\", 867], [\"LGA\", \"CAK\", 864], [\"LGA\", \"MEM\", 862], [\"EWR\", \"SNA\", 825], [\"JFK\", \"PDX\", 783], [\"EWR\", \"PWM\", 770], [\"LGA\", \"RSW\", 761], [\"EWR\", \"OMA\", 754], [\"JFK\", \"ORF\", 746], [\"LGA\", \"XNA\", 745], [\"EWR\", \"GSP\", 745], [\"JFK\", \"CMH\", 742], [\"LGA\", \"SRQ\", 737], [\"EWR\", \"SAV\", 736], [\"JFK\", \"DFW\", 732], [\"JFK\", \"BNA\", 730], [\"EWR\", \"CMH\", 724], [\"EWR\", \"GRR\", 719], [\"JFK\", \"HOU\", 714], [\"JFK\", \"CLE\", 707], [\"JFK\", \"DEN\", 703], [\"JFK\", \"IND\", 689], [\"JFK\", \"LGB\", 668], [\"LGA\", \"PHL\", 607], [\"JFK\", \"BQN\", 599], [\"EWR\", \"ORF\", 584], [\"EWR\", \"PDX\", 571], [\"EWR\", \ ...

# %% [markdown]
# Page 1 shows the top 10 destinations for EWR. JFK starts on page 9, and LGA on page 16.
#
# Top 10 for EWR: ORD, BOS, SFO, CLT, STL, MCO, LAX, IAH, FLL, DTW
#
# Top 10 for JFK: LAX, SFO, BOS, MCO, SJU, FLL, LAS, BUF, MIA, DCA
#
# Top 10 for LGA: ATL, ORD, CLT, MIA, DTW, DFW, DCA, BOS, FLL, MSP
#
# For each, it looks like their top destinations are in different parts of the county, but with a lot of major overlap to major cities throughout the United States, primarily.
#
# The top 10 TOTAL: LAX, ATL, ORD, SFO, CLT, ORD, BOS, MIA, MCO, BOS
#
# Its very interseting that ORD is listed twice - once from EWR and once from LGA. That means its the highest total destination, across two airports.

# %% [markdown]
# ***Question 2***

# %%
my_new_columns = ['origin', 'carrier']
DF2 = DF[my_new_columns]
DF2

show(DF2.groupby('origin')['carrier'].value_counts())
show(DF2.value_counts(ascending= False))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_80528d88_fa7f_4e18_9ceb_18e8648aa2c8"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_80528d88_fa7f_4e18_9ceb_18e8648aa2c8:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>origin</th>\n      <th>carrier</th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"EWR\", \"UA\", 46087], [\"EWR\", \"EV\", 43939], [\"EWR\", \"B6\", 6557], [\"EWR\", \"WN\", 6188], [\"EWR\", \"US\", 4405], [\"EWR\", \"DL\", 4342], [\"EWR\", \"AA\", 3487], [\"EWR\", \"MQ\", 2276], [\"EWR\", \"VX\", 1566], [\"EWR\", \"9E\", 1268], [\"EWR\", \"AS\", 714], [\"EWR\", \"OO\", 6], [\"JFK\", \"B6\", 42076], [\"JFK\", \"DL\", 20701], [\"JFK\", \"9E\", 14651], [\"JFK\", \"AA\", 13783], [\"JFK\", \"MQ\", 7193], [\"JFK\", \"UA\", 4534], [\"JFK\", \"VX\", 3596], [\"JFK\", \"US\", 2995], [\"JFK\", \"EV\", 1408], [\"JFK\", \"HA\", 342], [\"LGA\", \"DL\", 23067], [\"LGA\", \"MQ\", 16928], [\"LGA\", \"AA\", 15459], [\"LGA\", \"US\", 13136], [\"LGA\", \"EV\", 8826], [\"LGA\", \"UA\", 8044], [\"LGA\", \"WN\", 6087], [\"LGA\", \"B6\", 6002], [\"LGA\", \"FL\", 3260], [\"LGA\", \"9E\", 2541], [\"LGA\", \"F9\", 685], [\"LGA\", \"YV\", 601], [\"LGA\", \"OO\", 26]]"};
#         new ITable(table, dt_args);
#     });
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_e55582e4_0521_4ef7_8009_76d33d2808bc"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_e55582e4_0521_4ef7_8009_76d33d2808bc:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>origin</th>\n      <th>carrier</th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"EWR\", \"UA\", 46087], [\"EWR\", \"EV\", 43939], [\"JFK\", \"B6\", 42076], [\"LGA\", \"DL\", 23067], [\"JFK\", \"DL\", 20701], [\"LGA\", \"MQ\", 16928], [\"LGA\", \"AA\", 15459], [\"JFK\", \"9E\", 14651], [\"JFK\", \"AA\", 13783], [\"LGA\", \"US\", 13136], [\"LGA\", \"EV\", 8826], [\"LGA\", \"UA\", 8044], [\"JFK\", \"MQ\", 7193], [\"EWR\", \"B6\", 6557], [\"EWR\", \"WN\", 6188], [\"LGA\", \"WN\", 6087], [\"LGA\", \"B6\", 6002], [\"JFK\", \"UA\", 4534], [\"EWR\", \"US\", 4405], [\"EWR\", \"DL\", 4342], [\"JFK\", \"VX\", 3596], [\"EWR\", \"AA\", 3487], [\"LGA\", \"FL\", 3260], [\"JFK\", \"US\", 2995], [\"LGA\", \"9E\", 2541], [\"EWR\", \"MQ\", 2276], [\"EWR\", \"VX\", 1566], [\"JFK\", \"EV\", 1408], [\"EWR\", \"9E\", 1268], [\"EWR\", \"AS\", 714], [\"LGA\", \"F9\", 685], [\"LGA\", \"YV\", 601], [\"JFK\", \"HA\", 342], [\"LGA\", \"OO\", 26], [\"EWR\", \"OO\", 6]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# #lookup funciton to pull the names from the airports data set
#
# UA (United Airlines)
# EV (ExpressJet Airlines)
# B6 (JetBlue Airways)
# DL (Delta Air Lines Inc.)
# MQ (Envoy Air)
# AA (American Airlines)
# 9E (Endeavor Air Inc.)
# US (US Airways Inc.)
#
# These airlines have the highest number of departures of flights from New York airports in 2013. (Less than 10 total airlines due to doubling up of some airport destinations from different origins).

# %%
file_name = 'airlines'
file_location = 'https://joannabieri.com/introdatascience/data/'+file_name+'.csv'
DF_airlines = pd.read_csv(file_location)
show(DF_airlines)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_55ecc2f9_4899_4252_ba0a_4c45fc2c1f2b"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_55ecc2f9_4899_4252_ba0a_4c45fc2c1f2b:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>carrier</th>\n      <th>name</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"9E\", \"Endeavor Air Inc.\"], [\"AA\", \"American Airlines Inc.\"], [\"AS\", \"Alaska Airlines Inc.\"], [\"B6\", \"JetBlue Airways\"], [\"DL\", \"Delta Air Lines Inc.\"], [\"EV\", \"ExpressJet Airlines Inc.\"], [\"F9\", \"Frontier Airlines Inc.\"], [\"FL\", \"AirTran Airways Corporation\"], [\"HA\", \"Hawaiian Airlines Inc.\"], [\"MQ\", \"Envoy Air\"], [\"OO\", \"SkyWest Airlines Inc.\"], [\"UA\", \"United Air Lines Inc.\"], [\"US\", \"US Airways Inc.\"], [\"VX\", \"Virgin America\"], [\"WN\", \"Southwest Airlines Co.\"], [\"YV\", \"Mesa Airlines Inc.\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ***Question 3***

# %%
DF['arr_delay'].replace('NaN','NA',inplace=True)
filter_columns = ['arr_delay', 'carrier']
DF = DF[DF['arr_delay'].notna()]
DF_filter = DF[filter_columns]


DF_filter.groupby('carrier').mean().sort_values(by='arr_delay')
# Out:
#          arr_delay
# carrier
# AS       -9.930889
# HA       -6.915205
# AA        0.364291
# DL        1.644341
# VX        1.764464
# US        2.129595
# UA        3.558011
# 9E        7.379669
# B6        9.457973
# WN        9.649120
# MQ       10.774733
# OO       11.931034
# YV       15.556985
# EV       15.796431
# FL       20.115906
# F9       21.920705

# %% [markdown]
# a. Highest mean arrival delay - F9 (Frontier Airlines) with an average of 21.9 minutes.
#
# b. Lowest mean arrival delay - AS (Alaska Airlines) with an average -9.9 minute delay meaning they, on average, arrive 9 minutes earlier than scheduled.

# %% [markdown]
# ***Question 4***

# %%
DF['dep_time'].replace('NaN','NA',inplace=True)
DF = DF[DF['dep_time'].notna()]

mask_0_6 = (DF['dep_time'] >= 0) & (DF['dep_time'] <= 600)
mask_6_12 = (DF['dep_time'] > 600) & (DF['dep_time'] <= 1200)
mask_12_18 = (DF['dep_time'] > 1200) & (DF['dep_time'] <= 1800)
mask_18_24 = (DF['dep_time'] > 1800) & (DF['dep_time'] <= 2359)

DF_0_6 = DF[mask_0_6]
DF_6_12 = DF[mask_6_12]
DF_12_18 = DF[mask_12_18]
DF_18_24 = DF[mask_18_24]

dep_columns = ['dep_time', 'dep_delay']


#above - actual departure time
#below - scheduled departure time

mask_0_6s = ((DF['sched_dep_time'] >= 0) & (DF['sched_dep_time'] <= 600))
mask_6_12s = ((DF['sched_dep_time'] > 600) & (DF['sched_dep_time'] <= 1200))
mask_12_18s = ((DF['sched_dep_time'] > 1200) & (DF['sched_dep_time'] <= 1800))
mask_18_24s = ((DF['sched_dep_time'] > 1800) & (DF['sched_dep_time'] <= 2359))

DF_0_6s = DF[mask_0_6s]
DF_6_12s = DF[mask_6_12s]
DF_12_18s = DF[mask_12_18s]
DF_18_24s = DF[mask_18_24s]

sched_dep_columns = ['sched_dep_time', 'dep_delay']

show(DF_0_6[dep_columns].mean())
show(DF_6_12[dep_columns].mean())
show(DF_12_18[dep_columns].mean())
show(DF_18_24[dep_columns].mean())

show(DF_0_6s[sched_dep_columns].mean())
show(DF_6_12s[sched_dep_columns].mean())
show(DF_12_18s[sched_dep_columns].mean())
show(DF_18_24s[sched_dep_columns].mean())
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_d1eabe62_8e3a_409c_81c5_64c25a15b06f"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_d1eabe62_8e3a_409c_81c5_64c25a15b06f:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>0</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"dep_time\", 488.902758], [\"dep_delay\", 15.358592]]"};
#         new ITable(table, dt_args);
#     });
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_1260d412_ce82_4ec9_b65b_4a67d45ce546"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_1260d412_ce82_4ec9_b65b_4a67d45ce546:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>0</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"dep_time\", 862.254135], [\"dep_delay\", 2.165862]]"};
#         new ITable(table, dt_args);
#     });
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_d60d55dd_683e_42af_b4e2_b23db2bc2a90"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_d60d55dd_683e_42af_b4e2_b23db2bc2a90:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>0</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"dep_time\", 1504.171935], [\"dep_delay\", 11.282837]]"};
#         new ITable(table, dt_args);
#     });
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_d19ddfe3_9c97_4d75_9250_4c9e80cb2ab9"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_d19ddfe3_9c97_4d75_9250_4c9e80cb2ab9:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>0</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"dep_time\", 1987.259983], [\"dep_delay\", 30.841756]]"};
#         new ITable(table, dt_args);
#     });
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_d78db344_7135_49dd_8fe5_1ca37fe63ab0"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_d78db344_7135_49dd_8fe5_1ca37fe63ab0:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>0</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"sched_dep_time\", 584.908273], [\"dep_delay\", 0.967753]]"};
#         new ITable(table, dt_args);
#     });
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_d5911877_6674_4161_92c4_556f3936147e"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_d5911877_6674_4161_92c4_556f3936147e:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>0</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"sched_dep_time\", 871.536632], [\"dep_delay\", 4.177912]]"};
#         new ITable(table, dt_args);
#     });
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_cabb6420_a6e8_4e7e_b5f8_efa456b9106a"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_cabb6420_a6e8_4e7e_b5f8_efa456b9106a:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>0</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"sched_dep_time\", 1511.668605], [\"dep_delay\", 15.919366]]"};
#         new ITable(table, dt_args);
#     });
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_f3cf04ff_1554_4c54_abe5_bb8237ea3019"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_f3cf04ff_1554_4c54_abe5_bb8237ea3019:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "classes": ["display", "nowrap"], "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>0</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"sched_dep_time\", 1971.944728], [\"dep_delay\", 23.045218]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
dep_columns = ['dep_time', 'dep_delay']

(DF_0_6s['dep_delay'] >0).sum()/(DF_0_6s['dep_delay']).sum()
# Out:
# np.float64(0.2137054044507241)

# %%
(DF_6_12s['dep_delay'] >0).sum()/(DF_6_12s['dep_delay']).sum()
# Out:
# np.float64(0.062247325987016884)

# %%
(DF_12_18s['dep_delay'] >0).sum()/(DF_12_18s['dep_delay']).sum()
# Out:
# np.float64(0.028995843793919448)

# %%
(DF_18_24s['dep_delay'] >0).sum()/(DF_18_24s['dep_delay']).sum()
# Out:
# np.float64(0.022514989264296542)

# %% [markdown]
# The highest average departure delay by actual departure time is during the last 6 hours of the day.
#
# a. The portion by time frame:
# midnight to 6a: .2137
# 6:01a to noon: .0622
# 12:01p to 6p: .0289
# 6:01p to midnight: .0225
#
# b. The amount that are delayed decrease throughout the day. However, the delays towards the end of the day are, on average, are longer, even with less of them overall.

# %% [markdown]
# ***Question 5***

# %%
DF.sort_values('air_time', ascending = False)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 151467  2013      3   17    1337.0            1335        2.0    1937.0
# 115752  2013      2    6     853.0             900       -7.0    1542.0
# 149618  2013      3   15    1001.0            1000        1.0    1551.0
# 151311  2013      3   17    1006.0            1000        6.0    1607.0
# 150547  2013      3   16    1001.0            1000        1.0    1544.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 115062  2013      2    5    1303.0            1315      -12.0    1342.0
# 153880  2013      3   19    2226.0            2145       41.0    2305.0
# 113682  2013      2    3    2153.0            2129       24.0    2247.0
# 176604  2013      4   13     537.0             527       10.0     622.0
# 13524   2013      1   16    1355.0            1315       40.0    1442.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 151467            1836       61.0      UA      15  N77066    EWR  HNL
# 115752            1540        2.0      HA      51  N389HA    JFK  HNL
# 149618            1530       21.0      HA      51  N388HA    JFK  HNL
# 151311            1530       37.0      HA      51  N380HA    JFK  HNL
# 150547            1530       14.0      HA      51  N384HA    JFK  HNL
# ...                ...        ...     ...     ...     ...    ...  ...
# 115062            1411      -29.0      EV    4368  N13955    EWR  BDL
# 153880            2246       19.0      EV    4276  N16987    EWR  BDL
# 113682            2224       23.0      EV    4619  N13913    EWR  PHL
# 176604             628       -6.0      EV    4631  N12167    EWR  BDL
# 13524             1411       31.0      EV    4368  N16911    EWR  BDL
#
#         air_time  distance  hour  minute            time_hour
# 151467     695.0    4963.0  13.0    35.0  2013-03-17 17:00:00
# 115752     691.0    4983.0   9.0     0.0  2013-02-06 14:00:00
# 149618     686.0    4983.0  10.0     0.0  2013-03-15 14:00:00
# 151311     686.0    4983.0  10.0     0.0  2013-03-17 14:00:00
# 150547     683.0    4983.0  10.0     0.0  2013-03-16 14:00:00
# ...          ...       ...   ...     ...                  ...
# 115062      21.0     116.0  13.0    15.0  2013-02-05 18:00:00
# 153880      21.0     116.0  21.0    45.0  2013-03-20 01:00:00
# 113682      21.0      80.0  21.0    29.0  2013-02-04 02:00:00
# 176604      20.0     116.0   5.0    27.0  2013-04-13 09:00:00
# 13524       20.0     116.0  13.0    15.0  2013-01-16 18:00:00
#
# [327346 rows x 19 columns]

# %% [markdown]
# Index - 151467

# %%
file_name = 'planes'
file_location = 'https://joannabieri.com/introdatascience/data/'+file_name+'.csv'
DF_planes = pd.read_csv(file_location)
DF_planes
# Out:
#      tailnum    year                     type                   manufacturer  \
# 0     N10156  2004.0  Fixed wing multi engine                        EMBRAER
# 1     N102UW  1998.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 2     N103US  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 3     N104UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 4     N10575  2002.0  Fixed wing multi engine                        EMBRAER
# ...      ...     ...                      ...                            ...
# 3317  N997AT  2002.0  Fixed wing multi engine                         BOEING
# 3318  N997DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS AIRCRAFT CO
# 3319  N998AT  2002.0  Fixed wing multi engine                         BOEING
# 3320  N998DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
# 3321  N999DN  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
#
#           model  engines  seats  speed     engine
# 0     EMB-145XR        2     55    NaN  Turbo-fan
# 1      A320-214        2    182    NaN  Turbo-fan
# 2      A320-214        2    182    NaN  Turbo-fan
# 3      A320-214        2    182    NaN  Turbo-fan
# 4     EMB-145LR        2     55    NaN  Turbo-fan
# ...         ...      ...    ...    ...        ...
# 3317    717-200        2    100    NaN  Turbo-fan
# 3318      MD-88        2    142    NaN  Turbo-fan
# 3319    717-200        2    100    NaN  Turbo-fan
# 3320      MD-88        2    142    NaN  Turbo-jet
# 3321      MD-88        2    142    NaN  Turbo-jet
#
# [3322 rows x 9 columns]

# %%
max_airtime = DF['arr_time'].max()
row = DF.loc[max_airtime]

# %% [markdown]
# a. This flight was 1937 minutes long, or 32.38 hours (really??)
#
# b. That flight flew to HNL ( )
# **I am sure this is Honolulu- why is it not in the airports data set?**
#
# c. This flight had 292 seats.

# %% [markdown]
# ***Question 6***

# %%
DF_airports
# Out:
#       faa                           name        lat         lon     alt   tz  \
# 0     04G              Lansdowne Airport  41.130472  -80.619583  1044.0 -5.0
# 1     06A  Moton Field Municipal Airport  32.460572  -85.680028   264.0 -6.0
# 2     06C            Schaumburg Regional  41.989341  -88.101243   801.0 -6.0
# 3     06N                Randall Airport  41.431912  -74.391561   523.0 -5.0
# 4     09J          Jekyll Island Airport  31.074472  -81.427778    11.0 -5.0
# ...   ...                            ...        ...         ...     ...  ...
# 1453  ZUN                     Black Rock  35.083228 -108.791778  6454.0 -7.0
# 1454  ZVE         New Haven Rail Station  41.298669  -72.925992     7.0 -5.0
# 1455  ZWI      Wilmington Amtrak Station  39.736667  -75.551667     0.0 -5.0
# 1456  ZWU       Washington Union Station  38.897460  -77.006430    76.0 -5.0
# 1457  ZYP                   Penn Station  40.750500  -73.993500    35.0 -5.0
#
#      dst             tzone
# 0      A  America/New_York
# 1      A   America/Chicago
# 2      A   America/Chicago
# 3      A  America/New_York
# 4      A  America/New_York
# ...   ..               ...
# 1453   A    America/Denver
# 1454   A  America/New_York
# 1455   A  America/New_York
# 1456   A  America/New_York
# 1457   A  America/New_York
#
# [1458 rows x 8 columns]

# %% [markdown]
# **Does the contiguous US long/ lat remove the parts of Canada and South America? How do we combat this?

# %% [markdown]
# ***Question 7***

# %%
DF['arrival'] = DF['arr_delay'].apply(lambda x: 'ontime' if x <= 0 else 'delayed')
DF
#using the filtered data with the removed the NA values

#I used your hint and Stack Overflow to understand the 
#syntax of an if/else in the lambda function
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336765  2013      9   30    2240.0            2245       -5.0    2334.0
# 336766  2013      9   30    2240.0            2250      -10.0    2347.0
# 336767  2013      9   30    2241.0            2246       -5.0    2345.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
#
#         sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# 0                  819       11.0      UA  ...   N14228    EWR  IAH    227.0
# 1                  830       20.0      UA  ...   N24211    LGA  IAH    227.0
# 2                  850       33.0      AA  ...   N619AA    JFK  MIA    160.0
# 3                 1022      -18.0      B6  ...   N804JB    JFK  BQN    183.0
# 4                  837      -25.0      DL  ...   N668DN    LGA  ATL    116.0
# ...                ...        ...     ...  ...      ...    ...  ...      ...
# 336765            2351      -17.0      B6  ...   N354JB    JFK  SYR     41.0
# 336766               7      -20.0      B6  ...   N281JB    JFK  BUF     52.0
# 336767               1      -16.0      B6  ...   N346JB    JFK  ROC     47.0
# 336768            2358        1.0      B6  ...   N565JB    JFK  BOS     33.0
# 336769             350      -25.0      B6  ...   N516JB    JFK  PSE    196.0
#
#         distance  hour  minute            time_hour  arrival avg_delay
# 0         1400.0   5.0    15.0  2013-01-01 10:00:00  delayed       2.0
# 1         1416.0   5.0    29.0  2013-01-01 10:00:00  delayed       4.0
# 2         1089.0   5.0    40.0  2013-01-01 10:00:00  delayed       2.0
# 3         1576.0   5.0    45.0  2013-01-01 10:00:00   ontime      -1.0
# 4          762.0   6.0     0.0  2013-01-01 11:00:00   ontime      -6.0
# ...          ...   ...     ...                  ...      ...       ...
# 336765     209.0  22.0    45.0  2013-10-01 02:00:00   ontime      -5.0
# 336766     301.0  22.0    50.0  2013-10-01 02:00:00   ontime     -10.0
# 336767     264.0  22.0    46.0  2013-10-01 02:00:00   ontime      -5.0
# 336768     187.0  22.0    55.0  2013-10-01 02:00:00  delayed      12.0
# 336769    1617.0  23.0    59.0  2013-10-01 03:00:00   ontime     -10.0
#
# [327346 rows x 21 columns]

# %%
mask_dest = (DF['dest'] == 'PHL') | (DF['dest'] == 'RDU') & (DF['month'] == 12)
DF_mask = DF[mask_dest]

fig = px.box(DF_mask, 
             x = 'arrival', 
             y = 'dep_delay', 
             color= "dest",
             color_discrete_map={
                 'PHL': 'gold',
                 'RDU': 'lightblue'
             },
             facet_col= "origin", 
             facet_row = "dest")

fig.update_layout(title = "Ontime Performance of NYC Flights - Month of December",
                  title_x = .5,
                  yaxis_title = "Departure Delay")
fig.update_xaxes(title_text=None)

#This is the closest I could get - why do I have 6 but you only have 5? I am definitely missing something here!

# %% [markdown]
# ***Question 8***

# %%
#Let's look at the highest average delay by origin.

avg_delay = DF.groupby('origin')['dep_delay'].mean().reset_index()

fig = px.bar(avg_delay, 
             x = 'origin', 
             y ='dep_delay', 
             title = 'Average Departure Delay by Origin',
            color_discrete_sequence = ['hotpink'])

fig.update_layout(title_x = .5,
                  xaxis_title = "NYC Airport - Origin",
                  yaxis_title = "Average Delay")
                  
fig.show()
