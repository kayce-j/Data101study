# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 13
# ---------------------------------------
#
# GOALS:
#
# 1. Explore and respond to ideas around data ethics
# 2. Recreate other peoples work to more honestly reflect data.
#
# ----------------------------------------------------------
#
# This homework has **4 questions** and **1 exercise**

# %% [markdown]
# ## Important Information
#
# - Email: [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# - Office Hours: Duke 209 <a href="https://joannabieri.com/schedule.html"> Click Here for Joanna's Schedule</a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# This stops a few warning messages from showing
pd.options.mode.chained_assignment = None 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Data Science Ethics
#
# ## Misrepresentation
#
# Misrepresentation can happen intentionally or unintentionally. It can arise because of lack of knowledge of competence in data science. It is important to be aware of misrepresentation and be able to spot it a mile away in your work and in other peoples work!
#
# What is wrong with this picture? How would you correct it?
#
#
# ![Confirmed Covid Cases](images/ga-dph-declining-bars.jpg)
#
# - Overall this looks like the heights of bars are going down.
# - Dates are on the x-axis.
# - Are covid cases going down over time?
#
# **Q1** Write in your own words what you see that is wrong with this graph. What is the story it is telling vs the real story in the data?
#
#
# **Q2** Is it okay to misrepresent your data if you are getting people to "do the right thing"? For example, more exercise is good for you, right? Was it so bad to misrepresent the results of the cancer and exercise studies?

# %% [markdown]
# Q1 - These dates aren't in order! They are sorted in a descending order but not by date. This is a very strange way to order this information.
#
# Q2 - It is not. As mentioned in the lecture, in a scientific field we have a duty to maintain academic honesty. Using information to influence the public deceptively is not only unethical, but if you are found out you lose credibility. I think it is much more important to maintain credibility and allow the public to form opinions than "do good" through deception.

# %% [markdown]
# ## Data Privacy
#
# The question of data privacy is complicated and rests on the idea of what amount of expected privacy are we entitled to when we put our data online.
#
# ## Data Privacy -  Case study:
#
# **Q3** When analyzing data that is publicly shared, how can you make sure that you are not violating a persons reasonable expectation of privacy? What do you think the rules should be here? How would you want your data treated?
#
# **Q4** Does the answer to the question "Should I scrape this data" vary based on what the data is about? Give two examples where the answer might be different.

# %% [markdown]
# Q3 - I think that any information that is intended to by shared publicly (public posts on social media, or comments on public posts with their name attached to them) is not 'private' and should not be considered as such. Anything behind a login or anything that is shared privately (emails, private social media posts, dating app messages, purchase history), I believe are things that should be considered private and would be reasonable to assume that people expect those to be private. If you had to login, or if it wasn't already available to be seen publicly, there is reason to believe it should be private.
#
# Q4 - It would absolutely vary based on what the data is about. Information that again is public facing already - comments on social media, content they put out, who they are friends with or who they follow. I know I am focusing on social media a lot, but to me it is easy to see the distinciton here. If they are private users, then anything posted shouldn't be available publicly and shouldn't be scraped. And even on public profiles, things like their personal messages or drafts of posts should not be available to scrape and would be reasonable to be wanting to keep those private. With the example of OKCupid - even though it is "public" data - the data is supposed to only be avaialble if you are on the app, meaning there is an expectation that the information would stay within the app. I understand that regardless of the fact that it was public, that information should not have been scraped without the reasonable expectation of somehow anonymizing the data.

# %% [markdown]
# ## Exercise 1
#
# Consider the following visualization that was shared on Twitter:
#
# Originally from: https://twitter.com/JonBoeckenstedt/status/1291602888376999936
#
# ![Masks v. No Masks](images/masks-v-nomasks.png)
#
# You are going to construct the data by reading (approximate is okay) the numbers from the picture.
#
# 1. What is most misleading about this graph - essay answer
#
# 2.  Create a data frame that can be used to re-construct this visualization. You may need to guess some of the numbers, that's ok. You should first think about how many rows and columns you'll need and what you want to call your variables.
#
#
# Here is some code to get you started:

# %% [markdown]
# Q1 - The most misleading thing about this graph is the two different scaled axis on each side of the graph. Because they have very different values for the two differnt lines, it is making it appear that the two sets of data overlap and have close coorelation when in fact they do not. This is not only misleading as it makes people see there to be a much closer relationship between the masked and non masked counties and their COVID case rates, but it also is clearly skewed to make people believe something about wearing masks and their efficacy.

# %%
# Literally read the x, y numbers and enter them into a pandas dataframe. Then re-do the graph.

# Dates from the x-axis
date = ["7/12/2020", "7/13/2020", '7/14/2020', '7/15/2020', '7/16/2020', '7/17/2020', '7/18/2020', '7/19/2020', '7/20/2020', '7/21/2020', '7/22/2020', '7/23/2020', '7/24/2020', '7/25/2020', '7/26/2020', '7/27/2020', '7/28/2020', '7/29/2020', '7/30/2020', '7/31/2020', '8/1/2020', '8/2/2020', '8/3/2020']
# Numbers for mask data line y-axis LEFT SIDE
count_mask = [25.5, 19.5, 19.5, 20.5, 20, 20, 20.5, 20, 20.5, 21.5, 20, 20, 20.5, 19, 19.5, 17, 16.5, 16.75, 16.75, 16, 16.5, 16, 16 ]
# Numbers for the nomask data line y-axis RIGHT SIDE
count_nomask = [9.75, 9.5, 9.5, 9.9, 10, 9.5, 9, 8.5, 8.5, 8.75, 8.5, 8.4, 9.9, 10, 10.1, 9.5, 9.5, 9.5, 10, 8.9, 9, 8.9, 9.1]

DF = pd.DataFrame()
DF['date']=date
DF['count_mask']=count_mask 
DF['count_nomask']=count_nomask
DF
# Out:
#          date  count_mask  count_nomask
# 0   7/12/2020       25.50          9.75
# 1   7/13/2020       19.50          9.50
# 2   7/14/2020       19.50          9.50
# 3   7/15/2020       20.50          9.90
# 4   7/16/2020       20.00         10.00
# 5   7/17/2020       20.00          9.50
# 6   7/18/2020       20.50          9.00
# 7   7/19/2020       20.00          8.50
# 8   7/20/2020       20.50          8.50
# 9   7/21/2020       21.50          8.75
# 10  7/22/2020       20.00          8.50
# 11  7/23/2020       20.00          8.40
# 12  7/24/2020       20.50          9.90
# 13  7/25/2020       19.00         10.00
# 14  7/26/2020       19.50         10.10
# 15  7/27/2020       17.00          9.50
# 16  7/28/2020       16.50          9.50
# 17  7/29/2020       16.75          9.50
# 18  7/30/2020       16.75         10.00
# 19  7/31/2020       16.00          8.90
# 20   8/1/2020       16.50          9.00
# 21   8/2/2020       16.00          8.90
# ...

# %% [markdown]
# 3. Make a visualization of this data that is more accurate. Your visualization should more honestly tell the story.
#
#                fig = pd.line(DF,x= ,y= )
#
#
# 5. What message is more clear in your visualization, compared to the one posted on twitter?
# 6. What, if any, useful information do these data and your visualization tell us about mask wearing and COVID? It’ll be difficult to set aside what you already know about mask wearing, but you should try to focus only on what this visualization tells. Feel free to also comment on whether that lines up with what you know about mask wearing.
# 7. Could there be confounding data? What can you actually say about the data as given?

# %%
fig = px.line(DF, x= 'date', y=['count_mask', 'count_nomask'], title= 'Kansas COVID-19 7-Day Rolling Average of Daily Cases/Per 100K Population', 
             subtitle= 'Mask Counties Vs. No-Mask Mandate Counties',
             hover_data= 'value')

fig.update_layout(title_x=.5)
    
fig.show()

# %% [markdown]
# This graph shows that no mask counties have lower rates of COVID-19 cases per 100k people in Kansas during this time period. This could be sued to deny the efficacy of masks, but it also may have several confounding variables. Some counties in Kansas are very low population, and it woul dbe much more reasonable in those counties for people to interact with less people during a day and overall have more social distancing, which was another tactic employed to reduce the number of cases. However, typically masked counties may have been naturally more dense and even with the mandata, there is not guarantee that it is being practiced and there may be less compliance even with the mandate. Further, if we looked at the percentage of the population versus per 100k people, we may also see different data. However, there is no reason to have shown this data in its original state (with the skewed axis). If the data does nt support your hypothesis, it is worth digging into confounding varaiables and explanations and get curious with how the data came to be, rather than mislead people with the data you do have in order to try and make a point.
