# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 14
# ---------------------------------------
#
# GOALS:
#
# 1. Reflect on Algorithmic bias
# 2. Consider your role in Data Ethics
# 3. Report on your reading.
#
# ----------------------------------------------------------
#
# This homework has **3 questions** and **1 reading report**

# %% [markdown]
# ## Important Information
#
# - Email: [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# - Office Hours: Duke 209 <a href="https://joannabieri.com/schedule.html"> Click Here for Joanna's Schedule</a>
#
# ## If you start having trouble with git!!!
#
# Some people have reported that GIT is disappearing or giving errors on when they try to use it in Jupyter Lab. Here is another option for interacting with git:
#
# [Git Desktop](https://github.com/apps/desktop)
#
# If yous start having errors, try downloading this app. I can show you how to use it in class.

# %% [markdown]
# ## Report on your Data Ethics reading:
#
# **Your answers should be written as neatly as possible in Markdown cells**
#
# Your homework for today is all essay and written work. Make sure you respond to the three questions in the lecture:
#
# **Q1** What is your response to our discussion of bias in algorithms? Talk about the pluses and minuses of using algorithms to make decisions in our human world.
#
# **Q2**
# How do you train yourself to make the right decisions (or reduce the likelihood of accidentally making the wrong decisions) at those points?
#
# **Q3**
# How do you respond when you see bias in someones work? How could you take action to educate others?
#
#
# **Reading Report**
#
# Write a report about what you learned from your ethics reading exploration. For each book/article you read:
#
# 1. Include a full proper reference to the book/article.
#    * BOOK: Author last name, First name. Book Title: Subtitle. Edition, Publisher, Year.
#    * ONLINE ARTICLE: Author last name, First name. Article Title. Website name, date accessed. html link.
#    * [MLA styles for citing other types of online work](https://style.mla.org/works-cited/citations-by-format/online-works/?gad_source=1)
# 2. Write a summary in your own words what the book/article was about. Imagine telling your classmates about what they would learn by reading the article.
# 3. Discuss your own reaction to the book/article. Did it have any effect on how you think about data and ethics? Do you agree with the author? What specific ideas really stood out to you?

# %% [markdown]
# **Q1** Having previously watched Joy Buolamwini's Ted talk and read a lot of Cathy O'Niel's Weapons of Math Destruction, I am really drawn to this conversation around algorthimic bias. I am fascinated that there is so much to be uncovered when it comes to algorithms and machine learning that are using our flawed human data to make decisions. As mentioned in the lecture, anything trained on our already racist, homophobic, or otherwise inherently biased society, will have those in the model. Additionally, I was someone who genuinely believed that using machines to make some of these decisions could mean that bias could be removed from the equation - that we were better off letting "infallable data" make decisions. I think it is disheartening that so many of these flawed practices were allowed to be sustained for so long. I have to, however, have empathy when I am leaning towards frustraion about this because it couldn't have been intentional that there are algorithms with such bias imbedded in them. I can only imagine any data sceintist was even trying to eliminate the need for our bias to be involved in the process and creating efficiency and finding ways to streamline feels like a worthwhile endeavor. It is clear that there wasn't always full consideration for the ways in whih data was already biased like in the case of criminal justice or historic red lining. It is, however, clear to me that we have work to do, as data sceintists, to actively confront our biases and find flaws in our machine learning models. It is not enough to say we didn't make something intentionally flawed, especially given the influence some of these algorithms have on the lives of so many people.

# %% [markdown]
# **Q2** For me, I think that I am always checking in with other people when I am thinking about making decisions. In this case, I would try and find a diverse group of opinions and peope to see if I missed somehthing or if there is a flaw I didn't quite consider. I love feedback and offering different perpectives in a room already, and find it is one of my strengths as a leader. I also am aware that I can advocate for people and yet I will not be able to fully encoompass a wide range of experiences. I am not afraid to say that I was wrong, or start again when it feels like I need a redo. I also am under the working assumption that these things are never "done." If I made one of thse algorithms, I would be testing and reworking it over and over, with it in use, to continue to refine and understand it better. It is never about being done for me, but rather fine tuning it over and over again.

# %% [markdown]
# **Q3** I pride myself on being someone who actively looks for voics that aren't being represented. I think that is the first step of elimintaing bias - is getting the most voices represented as possible. When I see that someone may be biased, specifically if they are looking at less persepectives than they should consider, I have never been too shy to say something. I always approach it in asking questions - have we considered x? That might work for y, but what about z? Allow it to be an opportunity for people to see where they're thinking could be opened up. I also try to be very receptive in those same conversations so that I can build trsut with those I work with. Building that trust and report with my people allows for us all to have more condid conversations and can promote an environment where we aren't afraid to call those things out. I also think as far as education goes, its not necessarily my reponsibility to teach but rather open up opportunites for others to learn. Ask questions, offer other persepctives, and be gentle and kind so that others can feel comfortable in trying new things.

# %% [markdown]
# **Reading Report**
#
# Halwai, Megha. Fair trade-off: balancing algorithms and ethics. TheActuary.com. Accessed March 31, 2026. https://www.theactuary.com/2024/03/07/fair-trade-balancing-algorithms-and-ethics.
#
# This article outlines the benefits of incoporating data science into the actuarial professions. The actuarial field benefits from the incoporation of statistical models and predictive algorithms in order to streamline their workflow. It also addressed the conversation of data ethics, referencing similar conversations around bias in initial, training data and the need to actively manage risk and ethics. The article looks at specifically scrutinizing model inputs and uncovering personal biases.
#
# This article outlines the ways in which the author sees as ways actuaries should move fowards into these uncharted waters. By leaning into regulatory processes and overcoming personal and structural biases, the author sees the integration of predictive modeling as a benefit to the actuary industry, as long as actuaries continue to be rigorous in their pursuit of a fair and just.
#
# I agree with the overall impressions of this article, but because it wasn't full of hard numbers and data, it also feels like it leans on ethos to convince. However, its not a hard sell. The ability for actuaries to work with large amounts of data is now a data science issue, and the ways in which we train people on how to handle the ethics of being allowed to that much data will shape the industry and public perception in the years to come. Its a very critical time to consider a role in the actuary field, and I am personally gravitating to the idea that this is such a pivotal time for data science and ethics here. I feel like more than anything, I want to make an impact, and even though it will be a long time before I am expert enough to make big decisions, I know that my ability to make small decisions around data ethics - both for myself and in calling out my peers - means that I feel really excited about entering the industry soon. It feels important; electric.

# %% [markdown]
# -------------------------------------------------------
#
# ## Further watching
#
# If you have time, really explore the world of data ethics. You could watch some of the videos linked from class.
#
# ### Weapons of Math Destruction | Cathy O'Neil | Talks at Google
#
# {{< video https://www.youtube.com/watch?v=TQHs8SA1qpk >}}
#
# ### Imagining a Future Free from the Algorithms of Oppression | Safiya Noble | ACL 2019
#
# {{< video https://www.youtube.com/watch?v=tNi_U1Bb1S0 >}}
#
# ### Whats An Algorithm Got To Do With It
#
# {{< video https://www.youtube.com/watch?v=5zxDwA99soA >}}
